# %% [markdown]
# <a href="https://colab.research.google.com/github/fahimaislam2022/Python-/blob/main/PY0101EN_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello, Python!')
# Out:
# Hello, Python!

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
frint("Hello, Python!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_757/3711947516.py in <cell line: 0>()
# ----> 1 frint("Hello, Python!")
#       2
#
# NameError: name 'frint' is not defined

# %%
print("Hello, Python!)
# Out:
#   File "/tmp/ipykernel_757/2908026681.py", line 1
#     print("Hello, Python!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("This will be printed")
frint("This will cause an error")
print("This will NOT be printed")
# Out:
# This will be printed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_757/3816931718.py in <cell line: 0>()
#       1 print("This will be printed")
# ----> 2 frint("This will cause an error")
#       3 print("This will NOT be printed")
#
# NameError: name 'frint' is not defined

# %% [markdown]
# <a align="center">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%201/images/TypesObjects.png" width="600">
# </a>

# %%
type(12)
# Out:
# int

# %%
type(2.14)
# Out:
# float

# %%
type("Hello, Python 101!")
# Out:
# str

# %% [markdown]
# <a align="center">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%201/images/TypesInt.png" width="600">
# </a>

# %% [markdown]
# Integers can be negative or positive numbers:

# %%
type(-1)
# Out:
# int

# %%
type(float(2))
# Out:
# float

# %%
int(1.1)
# Out:
# 1

# %%
int('1')
# Out:
# 1

# %%
float('1.2')
# Out:
# 1.2

# %%
int(True)
# Out:
# 1
